# %%
import matplotlib.pyplot as plt
import matplotlib
from importlib import reload
import numpy as np
print(1)
import mxp_tools.labs.watt_balance
# Out:
# 1

# %%
print(1)
# Out:
# 1

# %%
matplotlib.rcParams.update({'font.size': 18, 'text.usetex': True})

# %%
reload(mxp_tools.labs.watt_balance)
VelocityMode = mxp_tools.labs.watt_balance.VelocityMode

V = VelocityMode('vel-2-20190422.csv', [100,-100])
V.process()
# display(V.data['shifted'].shape)
plt.show()
# Out:
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:68: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   position = data[0].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:69: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   voltage = data[2].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:80: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   x_raw = raw_data[1].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:81: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   y_raw = raw_data[3].as_matrix()
# shift: -42
# LinregressResult(slope=23.529978451803338, intercept=0.04152596720585397, rvalue=0.8398029392123642, pvalue=0.0, stderr=0.30693250504442093)
# LinregressResult(slope=23.529978451803338, intercept=0.04152596720585397, rvalue=0.8398029392123642, pvalue=0.0, stderr=0.30693250504442093)

# %%
reload(mxp_tools.labs.watt_balance)
VelocityMode = mxp_tools.labs.watt_balance.VelocityMode

V = VelocityMode('vel-3-20190422.csv', [100,-100])
V.data.savgol_window=41
V.data.savgol_poly=1
V.process()
# display(V.data['shifted'].shape)
plt.show()
# Out:
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:68: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   position = data[0].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:69: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   voltage = data[2].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:80: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   x_raw = raw_data[1].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:81: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   y_raw = raw_data[3].as_matrix()
# shift: -31
# LinregressResult(slope=21.863761199240596, intercept=-0.00042680749179848385, rvalue=0.9890168048156093, pvalue=0.0, stderr=0.06179256139806214)
# LinregressResult(slope=21.863761199240596, intercept=-0.00042680749179848385, rvalue=0.9890168048156093, pvalue=0.0, stderr=0.06179256139806214)

# %%
import pandas
df = pandas.DataFrame(V.data.stage2)

df.to_csv('xy-1.csv')

# %% [markdown]
# It looks like there are two modes in the data...

# %% [markdown]
# The force mode measurement is shown in orange, and matches most closely with the weaker mode in the data. Will have to collect more data to confirm whether the more horizontal mode typically matches the data better.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
xy = V.data.stage2
V.scatter(xy, ax)

result = V.data.slope
x = np.linspace(min(xy[:,0]), max(xy[:,0]), 100)
y = result.slope*x+result.intercept
ax.plot(x, y, label='regression', alpha=0.6)

# y = 25.1021*x+result.intercept
# ax.plot(x, y, label='force mode 25.1', alpha=0.6)

# y = 45*x+result.intercept
# ax.plot(x, y, label='visual 45', alpha=0.6)

# y = 21*x+result.intercept
# ax.plot(x, y, label='visual 21', alpha=0.6)
# ax.legend()
ax.grid()
plt.show()

# %%
reload(mxp_tools.labs.watt_balance)
VelocityMode = mxp_tools.labs.watt_balance.VelocityMode

V = VelocityMode('vel-2-20190422.csv')
V.process()
# display(V.data['shifted'].shape)
plt.show()
# Out:
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:64: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   position = data[0].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:65: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   voltage = data[2].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:84: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   x_raw = raw_data[1].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:85: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   y_raw = raw_data[3].as_matrix()
# shift: -41
# LinregressResult(slope=23.876064785855004, intercept=0.03777621973372758, rvalue=0.8560779078258313, pvalue=1.7336561426024136e-190, stderr=0.5623783675835725)

# %% [markdown]
# Lol everything looks like a banana

# %%
reload(mxp_tools.labs.watt_balance)
VelocityMode = mxp_tools.labs.watt_balance.VelocityMode

V = VelocityMode('vel-3-20190426.csv')
V.process()
# display(V.data['shifted'].shape)
plt.show()
# Out:
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:64: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   position = data[0].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:65: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   voltage = data[2].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:84: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   x_raw = raw_data[1].as_matrix()
# /home/michael/Documents/College/Phys_4052/jupyter/mxp-tools/mxp_tools/labs/watt_balance.py:85: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   y_raw = raw_data[3].as_matrix()
# shift: -62
# LinregressResult(slope=35.700105948595294, intercept=4.168984077283913e-05, rvalue=0.9364975797285835, pvalue=0.0, stderr=0.2373184088310917)
